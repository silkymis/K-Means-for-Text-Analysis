# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import json

filepath="Enter JSON Filename
#json_file = open(filepath).read()
#questions = json.load(json_file)
#print(questions)

utterances = list()
with open(filepath) as json_file:
    data = json.load(json_file)
    for u in data['utterances']:
        utterances.append(u['text'])

        
vectorizer = TfidfVectorizer(stop_words='english')

X = vectorizer.fit_transform(utterances)


true_k = 5
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print

print("\n")
print("Prediction")

Y = vectorizer.transform(["home connection"])
prediction = model.predict(Y)
print(prediction)

Y = vectorizer.transform(["SAP"])
prediction = model.predict(Y)
print(prediction)
# Out:
# Top terms per cluster:
# Cluster 0:
#  phone
#  soft
#  calls
#  help
#  use
#  want
#  intel
#  network
#  anyconnect
#  connect
# Cluster 1:
#  need
#  vpn
#  help
#  hotspot
#  softphone
#  access
#  use
#  set
#  account
#  employee
# Cluster 2:
#  work
#  hotspot
#  does
#  home
#  vpn
#  phone
#  intel
#  need
#  won
#  softphone
# Cluster 3:
#  softphone
#  number
#  lync
#  desk
#  phone
#  use
#  help
#  like
#  set
#  calls
# Cluster 4:
#  vpn
#  hotspot
#  employee
#  use
#  access
#  connect
#  account
#  interns
#  set
#  cw
#
#
# Prediction
# [0]
# [0]
